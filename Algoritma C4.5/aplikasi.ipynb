# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'Menu.ui'
#
# Created by: PyQt5 UI code generator 5.15.7
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


import sys

import pandas as pd
from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtCore import QUrl, QFileInfo
from PyQt5.QtWidgets import QLabel, QFileDialog, QMessageBox
from PyQt5 import QtCore, QtGui, QtWidgets
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
# import model


class Ui_Form(object):
    def __init__(self):
        # self.tab_2 = None
        self.filename = None
        self.splitVal = None
        self.splitVal = None
        self.df = None
        self.lst = None
        self.data = None
        self.Accuracy = None
        self.confusion = None
        self.Precision = None
        self.Recall = None
        self.F1_score = None
        # self.model = model

    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(665, 503)
        self.tabWidget = QtWidgets.QTabWidget(Form)
        self.tabWidget.setGeometry(QtCore.QRect(10, 80, 651, 421))
        self.tabWidget.setObjectName("tabWidget")
        self.tab = QtWidgets.QWidget()
        self.tab.setObjectName("tab")
        self.label = QtWidgets.QLabel(self.tab)
        self.label.setGeometry(QtCore.QRect(100, 140, 101, 41))
        self.label.setObjectName("label")
        self.pruning = QtWidgets.QCheckBox(self.tab)
        self.pruning.setGeometry(QtCore.QRect(300, 150, 71, 21))
        self.pruning.setObjectName("pruning")
        self.save = QtWidgets.QPushButton(self.tab)
        self.save.setGeometry(QtCore.QRect(410, 140, 91, 31))
        self.save.setObjectName("save")
        self.save.clicked.connect(self.savefile)
        self.openfile = QtWidgets.QPushButton(self.tab)
        self.openfile.setGeometry(QtCore.QRect(410, 70, 91, 31))
        self.openfile.setObjectName("openfile")
        self.openfile.clicked.connect(self.openfilecsv)
        self.fileName = QtWidgets.QLineEdit(self.tab)
        self.fileName.setGeometry(QtCore.QRect(100, 70, 271, 31))
        self.fileName.setObjectName("fileName")
        self.spinBox = QtWidgets.QSpinBox(self.tab, value=1, prefix='0.')
        self.spinBox.setGeometry(QtCore.QRect(220, 150, 42, 22))
        self.spinBox.setObjectName("spinBox")
        self.tabWidget.addTab(self.tab, "")
        self.tab_5 = QtWidgets.QWidget()
        self.tab_5.setObjectName("tab_5")
        self.hasilklasifikasi = QtWidgets.QPushButton(self.tab_5)
        self.hasilklasifikasi.setGeometry(QtCore.QRect(0, 80, 101, 31))
        self.hasilklasifikasi.setObjectName("hasilklasifikasi")
        self.hasilklasifikasi.clicked.connect(self.clicked)
        self.label_3 = QtWidgets.QLabel(self.tab_5)
        self.label_3.setGeometry(QtCore.QRect(10, 10, 47, 13))
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.tab_5)
        self.label_4.setGeometry(QtCore.QRect(10, 30, 47, 13))
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.tab_5)
        self.label_5.setGeometry(QtCore.QRect(10, 50, 47, 13))
        self.label_5.setObjectName("label_5")
        self.tabWidget.addTab(self.tab_5, "")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(10, 30, 901, 41))
        self.label_6 = QtWidgets.QLabel(self.tab_5)
        self.label_6.setGeometry(QtCore.QRect(120, 10, 47, 13))
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(self.tab_5)
        self.label_7.setGeometry(QtCore.QRect(120, 30, 47, 13))
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(self.tab_5)
        self.label_8.setGeometry(QtCore.QRect(120, 50, 47, 13))
        self.label_8.setObjectName("label_8")
        self.scrollArea = QtWidgets.QTextEdit(self.tab_5, readOnly=True)
        self.scrollArea.setGeometry(QtCore.QRect(10, 120, 481, 111))
        self.scrollArea.setStyleSheet("background-color: rgb(255, 255, 255);")
        font = QtGui.QFont()
        font.setFamily("Cambria")
        font.setPointSize(9)
        font.setBold(True)
        font.setWeight(75)
        self.scrollArea.setFont(font)
        # self.scrollArea.setWidgetResizable(True)
        self.scrollArea.setObjectName("scrollArea")
        self.scrollAreaWidgetContents = QtWidgets.QWidget()
        self.scrollAreaWidgetContents.setGeometry(QtCore.QRect(0, 0, 449, 89))
        self.scrollArea_2 = QtWidgets.QTextEdit(self.tab_5, readOnly=True)
        self.scrollArea_2.setGeometry(QtCore.QRect(10, 240, 481, 111))
        self.scrollArea_2.setStyleSheet("background-color: rgb(255, 255, 255);")
        font = QtGui.QFont()
        font.setFamily("Cambria")
        font.setPointSize(9)
        font.setBold(True)
        font.setWeight(75)
        self.scrollArea_2.setFont(font)
        # self.scrollArea.setWidgetResizable(True)
        self.scrollArea_2.setObjectName("scrollArea_2")
        self.scrollAreaWidgetContents_2 = QtWidgets.QWidget()
        self.scrollAreaWidgetContents_2.setGeometry(QtCore.QRect(0, 0, 449, 89))
        font = QtGui.QFont()
        font.setFamily("Arial Black")
        font.setPointSize(16)
        font.setBold(True)
        font.setWeight(75)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        self.retranslateUi(Form)
        self.tabWidget.setCurrentIndex(0)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "APLIKASI"))
        self.label.setText(_translate("Form", "Tentukan Data Latih"))
        self.pruning.setText(_translate("Form", "Pruning"))
        self.save.setText(_translate("Form", "Save"))
        self.openfile.setText(_translate("Form", "Open File csv"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab), _translate("Form", "Kelola Data"))
        self.hasilklasifikasi.setText(_translate("Form", "Hasil Klasifikasi"))
        self.label_3.setText(_translate("Form", "Split Data"))
        self.label_4.setText(_translate("Form", "Dataset"))
        self.label_5.setText(_translate("Form", "Pruning"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_5), _translate("Form", "Klasifikasi"))
        self.label_2.setText(_translate("Form", "Klasifikasi Kepribadian Bedasarkan Big Five Personality"))

    def clicked(self):
        try:
            self.Classification()
            self.scrollArea_2.setPlainText("Accuracy:: "+ self.Accuracy +"/nPrecision:: "+ self.Precision)
            self.scrollArea.setPlainText("Confusion Matrix:: "+ self.confusion)
            # self.show_popupClassify()
        except:
            self.show_popupDataEmpty()

    def openfilecsv(self):
        fname, _ = QFileDialog.getOpenFileName(QtWidgets.QWidget(), "Open File", " ", "CSV File (*.csv)")
        self.filename = QFileInfo(fname).fileName()
        print(self.filename)
        if fname:
            self.fileName.setText(str(self.filename))
        self.show_popupImp()
        return self.filename

    def importFile(self):
        atr = ['Gender',
               'Age',
               'openness',
               'neuroticism',
               'conscientiousness',
               'agreeableness',
               'extraversion',
               'personality'
             ]
        fileName = self.filename
        print(fileName)
        self.data = pd.read_csv(fileName, sep=",",header=None, names=atr)
        print("Data berhasil Diimport")
        return self.data

    def Classification(self):
        features = ['Gender',
               'Age',
               'openness',
               'neuroticism',
               'conscientiousness',
               'agreeableness',
               'extraversion'
             ]
        dmFt =pd.get_dummies(self.data[features])
        X = self.data[features]
        y = self.data.personality

        split = '0.'+str(self.splitVal)
        Split = float(split)
        X_train, X_test, y_train, y_test = train_test_split(dmFt, y, test_size=Split, random_state=1)
        print(dmFt.head())
        print(Split)
        #
        dt = DecisionTreeClassifier()
        dtr = dt.fit(X_train,y_train)
        y_pred = dtr.predict(X_test)
        self.Accuracy = str(metrics.accuracy_score(y_test,y_pred))
        self.Precision = str(metrics.precision_score(y_test,y_pred))
        self.Recall = str(metrics.recall_score(y_test,y_pred))
        self.F1_score = str(metrics.f1_score(y_test,y_pred))
        self.confusion = str(metrics.confusion_matrix(y_test,y_pred))
        print("Accuracy:: ", self.Accuracy)
        print("Precision:: ", self.Precision)
        print("Recall :: ", self.Recall)
        print("F1 Scor :: ", self.F1_score)
        print("Confusion Matrix :: ", self.confusion)


    def savefile(self):
        try:
            self.importFile()
            self.fnames = (self.filename)
            self.splitVal = (self.spinBox.value())
            self.strval = (str(self.splitVal))
            self.label_6.setText('0.' + self.strval)
            self.prunVal = (self.pruning.isChecked())
            self.label_8.setText(str(self.prunVal))
            print("split data value = " + str(self.splitVal))
            print("prunning value = ", self.prunVal)
        except:
            self.show_popupDataEmpty()


    def show_popupDataEmpty(self):
        msg = QMessageBox()
        msg.setWindowTitle('Klasifikasi Kepribadian')
        msg.setText('Data Belum dI Import')
        x = msg.exec()

    def show_popupImp(self):
        msg = QMessageBox()
        msg.setWindowTitle('Klasifikasi Kepribadian')
        msg.setText('Data Berhasl Di Impor')
        x = msg.exec()


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
